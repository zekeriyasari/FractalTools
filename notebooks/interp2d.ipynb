# %% [markdown]
# # 2D Fractal Interpolation and Integration
#
# ## 2D Fractal Interpolation
#
# ### Theory
#
# We consider the interpolation of the data points given as
# $$
# P = \{ (x_i, y_i, z_i)~|~ x_i, y_i, z_i \in \mathbb{R}, \; i = 1, 2, \ldots, N \}
# $$
# where $N$ is the number of points, $(x_i, y_i) \in \Omega \subset \mathbb{R}^2, \; z_i \in \mathbb{R}$. $\Omega$ is the interpolation domain with the vertex points $\{(\tilde{x}_j, \tilde{y}_j, \tilde{z}_j)~|~j = 1, 2, 3\}$ is the interpolation domain and the points. The aim is to find a continous function, also called as interpolant $f: \Omega \mapsto \mathbb{R}$ such the interpolation points are satisfied, i.e. $f(x_i , y_i) = z_i, \; i  = 1, 2, \ldots, N$.

# %% [markdown]
# The type of IFS has the form
# $$
# w_n(x, y, z) = \begin{bmatrix}
# a_{11, n} & a_{12,n} & 0 \\
# a_{21, n} & a_{22,n} & 0 \\
# a_{31, n} & a_{32,n} & a_{33,n} \\
# \end{bmatrix}
# \begin{bmatrix}
# x \\
# y \\
# z
# \end{bmatrix} +
# \begin{bmatrix}
# b_{1,n} \\
# b_{2,n } \\
# b_{3,n}
# \end{bmatrix}
# \quad n = 1, 2, \ldots, K
# $$
# where $K$ is the number of triangles in $\Omega$.

# %% [markdown]
# Given the free variables $a_{33, n}, \; n = 1, 2, \ldots, K$, the remaining unknown coefficients in the transformations can be calculated using boundary conditions.
# $$
# \begin{aligned}
# w_n(\tilde{x}_1, \tilde{y}_1, \tilde{z}_1) &= (x_{1,n}, y_{1, n}, z_{1, n}) \\
# w_n(\tilde{x}_2, \tilde{y}_2, \tilde{z}_2) &= (x_{2,n}, y_{2, n}, z_{2, n}) \\
# w_n(\tilde{x}_3, \tilde{y}_3, \tilde{z}_3) &= (x_{3,n}, y_{3, n}, z_{3, n}) \\
# \end{aligned}
# \quad n = 1, 2, \ldots, K
# $$
# Hence, from the boundary conditions, we have
# $$
# \begin{aligned}
#     a_{11, n} \tilde{x}_1 + a_{12, n} \tilde{y}_1 + b_{1, n} &= x_{1,n} \\
#     a_{11, n} \tilde{x}_2 + a_{12, n} \tilde{y}_2 + b_{1, n} &= x_{2,n} \\
#     a_{11, n} \tilde{x}_3 + a_{12, n} \tilde{y}_3 + b_{1, n} &= x_{3,n} \\
# \end{aligned}
# $$
# $$
# \begin{aligned}
#     a_{21, n} \tilde{x}_1 + a_{22, n} \tilde{y}_1 + b_{2, n} &= y_{1,n} \\
#     a_{21, n} \tilde{x}_2 + a_{22, n} \tilde{y}_2 + b_{2, n} &= y_{2,n} \\
#     a_{21, n} \tilde{x}_3 + a_{22, n} \tilde{y}_3 + b_{2, n} &= y_{3,n} \\
# \end{aligned}
# $$
# $$
# \begin{aligned}
#     a_{31, n} \tilde{x}_1 + a_{32, n} \tilde{y}_1 + b_{3, n} &= z_{1,n} - a_{33,n} \tilde{z}_1 \\
#     a_{31, n} \tilde{x}_2 + a_{32, n} \tilde{y}_2 + b_{3, n} &= z_{2,n} - a_{33,n} \tilde{z}_2 \\
#     a_{31, n} \tilde{x}_3 + a_{32, n} \tilde{y}_3 + b_{3, n} &= z_{3,n} - a_{33,n} \tilde{z}_3 \\
# \end{aligned}
# $$

# %% [markdown]
# More compactly,
# $$
# \begin{bmatrix}
#     \tilde{x}_1 & \tilde{y}_1 & 1 \\
#     \tilde{x}_2 & \tilde{y}_2 & 1 \\
#     \tilde{x}_3 & \tilde{y}_3 & 1 \\
# \end{bmatrix}
# \begin{bmatrix}
#     a_{11,n} & a_{21,n} & a_{31,n} \\
#     a_{12,n} & a_{22,n} & b_{32,n} \\
#     b_{1,n} & b_{2,n} & b_{3, n}
# \end{bmatrix} =
# \begin{bmatrix}
#     x_{1,n} & y_{1,n} & z_{1,n} - a_{33,n} \tilde{z}_1 \\
#     x_{2,n} & y_{2,n} & z_{2,n} - a_{33,n} \tilde{z}_2 \\
#     x_{3,n} & y_{3,n} & z_{3,n} - a_{33,n} \tilde{z}_3 \\
# \end{bmatrix}
# \quad n = 1, 2, \ldots, K
# $$

# %% [markdown]
# Solving these equations we have.
# $$
# \begin{bmatrix}
#     a_{11,n} & a_{21,n} & a_{31,n} \\
#     a_{12,n} & a_{22,n} & b_{32,n} \\
#     b_{1,n} & b_{2,n} & b_{3, n}
# \end{bmatrix} =
# \begin{bmatrix}
#     \tilde{x}_1 & \tilde{y}_1 & 1 \\
#     \tilde{x}_2 & \tilde{y}_2 & 1 \\
#     \tilde{x}_3 & \tilde{y}_3 & 1 \\
# \end{bmatrix}^{-1}
# \begin{bmatrix}
#     x_{1,n} & y_{1,n} & z_{1,n} - a_{33,n} \tilde{z}_1 \\
#     x_{2,n} & y_{2,n} & z_{2,n} - a_{33,n} \tilde{z}_2 \\
#     x_{3,n} & y_{3,n} & z_{3,n} - a_{33,n} \tilde{z}_3 \\
# \end{bmatrix}
# \quad n = 1, 2, \ldots, K
# $$

# %% [markdown]
# ### Application
#
# In this section, theoretical results obtained above will be justified numerically.

# %% [markdown]
# #### Regular Data Interpolation
#
# In this section, we will construct regular data interpolation. For this purpose, we will construct some data points first that are drawn from a regular function
# $$
# f(x, y) = x^2 + y^2 + 1
# $$
# The data points will be interpolate using the two-dimensional fractal interpolation outlined above. The relative error will be plotted to visualize the performance of the interpolation method.

# %%
# Load packges 
using FractalTools 
using GLMakie 

# Interpolation data 
f(x, y) = x^2 + y^2 + 1
Ω = uniformdomain(6, BigFloat)
N = 100 
pts = getdata(f, Ω, N)

# Interpolation
f̃ = interpolate(pts, Interp2D(0.001))

# Test Points 
tpts = getdata(Ω, N)

# Evaluations 
fvals = map(p -> f(p...), tpts)     # True values 
ivals = map(p -> f̃(p...), tpts)     # Interpolants
evals = abs.(fvals - ivals) ./ abs.(fvals) * 100    # Relative error

# Plots 
fig = Figure(resolution=(1200, 800))

ls1 = Axis3(fig[1, 1])
scatter!(ls1, pts)
wireframe!(ls1, tomesh(pts))
wireframe!(ls1, tomesh(project(pts)))
scatter!(ls1, tpts, color=:red, markersize=25)

ls2 = Axis3(fig[1, 2]) 
trisurf!(ls2, tpts, fvals)
wireframe!(ls2, tomesh(project(pts)))

ls3 = Axis3(fig[2, 1]) 
trisurf!(ls3, tpts, ivals)
wireframe!(ls3, tomesh(project(pts)))

ls4 = Axis3(fig[2, 2]) 
trisurf!(ls4, tpts, evals)
wireframe!(ls4, tomesh(project(pts)))

fig
# Out:
# Figure()

# %% [markdown]
# #### Irregular Data Interpolation
#
# In this section, we will interpolate points drawn from an a functon with an irregular graph.

# %%
# Load packges 
using FractalTools 
using GLMakie 

# Interpolation data 
ff = FractalTools.rastrigin
Ω = uniformdomain(6, BigFloat, zeros(2), 10)
N = 200 
pts = getdata(ff, Ω, N)

# Interpolation
f̃ = interpolate(pts, Interp2D(0.001))

# Test Points 
tpts = getdata(Ω, N)

# Evaluations 
fvals = map(p -> ff(p...), tpts)     # True values 
ivals = map(p -> f̃(p...), tpts)     # Interpolants
evals = abs.(fvals - ivals) ./ abs.(fvals) * 100    # Relative error

# Plots 
fig = Figure(resolution=(1200, 800))

ls1 = Axis3(fig[1, 1])
scatter!(ls1, pts)
wireframe!(ls1, tomesh(pts))
wireframe!(ls1, tomesh(project(pts)))
scatter!(ls1, tpts, color=:red, markersize=25)

ls2 = Axis3(fig[1, 2]) 
trisurf!(ls2, tpts, fvals)
wireframe!(ls2, tomesh(project(pts)))

ls3 = Axis3(fig[2, 1]) 
trisurf!(ls3, tpts, ivals)
wireframe!(ls3, tomesh(project(pts)))

ls4 = Axis3(fig[2, 2]) 
trisurf!(ls4, tpts, evals)
wireframe!(ls4, tomesh(project(pts)))

fig
# Out:
# Figure()

# %% [markdown]
# #### Effect of Free Variable
#
# To be included...

# %% [markdown]
# #### Mean Square Error versus Free Variable
#
# In this section, the effect of free variable on the mean square error is investigated.

# %%
# This file investigates MSE with respect to free variables 

using FractalTools 
using GeometryBasics
using GLMakie

# Construct interpolation data 
f1(x, y) = x^2 + y^2 + 1
Ω = uniformdomain(8, BigFloat)
npts = 100
pts = getdata(f1, Ω, npts)

# Construct test data 
tpts = getdata(Ω, npts)
ntpts = length(tpts)

# Compute errors 
fvals = map(pt -> f1(pt...), tpts) 
freevars = 0.001 : 0.001 : 0.025 
mse = map(freevars) do freevar 
    interp = interpolate(pts, Interp2D(freevar))
    ivals = map(pt -> interp(pt...), tpts)
    sum((fvals - ivals).^2) / ntpts
end 

# Plot mse 
fig = Figure() 
ax = fig[1, 1] = Axis(fig, xlabel="Free Variable", ylabel="MSE", title="2D Interpolation MSE") 
stem!(ax, freevars, mse, color=:black)
fig
# Out:
# Figure()

# %% [markdown]
# #### Comparison to Spline Interpolation
#
# In this file fractal interpolation methods ar going  to be copared to spline interpolation methods. For this purpose, twe will construct an interpolation data spit over a rectangular grid. Then the interpolation data will be interpolated using both fractal interpolation and spline interpolation.

# %%
# Load packages 
using GLMakie 
using GeometryBasics 
using FractalTools
import Interpolations
import Interpolations: Gridded, Linear

# Define test functions 
f(x, y) = x^2 + y^2 + 1

# Construct gridded data to construct and test interpolant 
ndata = 10 
ntest = 20
data_mesh_2d = GeometryBasics.mesh(Tesselation(Rect2D(BigFloat.([-1., -1, 2., 2.])...), (ndata, ndata)))
data_points_3d = [Point(pnt[1], pnt[2], f(pnt[1], pnt[2])) for pnt in data_mesh_2d.position]     # points to construct interpolants 
test_mesh_2d = GeometryBasics.mesh(Tesselation(Rect2D(BigFloat.([-1., -1, 2., 2.])...), (ntest, ntest)))
test_points_3d = [Point(pnt[1], pnt[2], f(pnt[1], pnt[2])) for pnt in test_mesh_2d.position]    # points to test interpolants

# Construct interpolants 
fractal_interpolant = FractalTools.interpolate(data_points_3d, Interp2D(0.001))
spline_interpolant = Interpolations.interpolate(
    (unique(getindex.(data_points_3d, 1)), unique(getindex.(data_points_3d, 2))),       # x-y gridded data 
    collect(reshape(getindex.(data_points_3d, 3), ndata, ndata)),                       # z values 
    Gridded(Linear())                                                                   # Interpolation type 
)

# Evaluations 
true_data_points                        = map(pnt -> Point(f(pnt[1], pnt[2])), data_points_3d)
true_test_points                        = map(pnt -> Point(f(pnt[1], pnt[2])), test_points_3d)

fractal_interpolant_data_points         = map(pnt -> Point(fractal_interpolant(pnt[1], pnt[2])), data_points_3d)
fractal_interpolant_test_points         = map(pnt -> Point(fractal_interpolant(pnt[1], pnt[2])), test_points_3d)
fractal_interpolant_data_points_error   = Point.( 
    abs.(last.(true_data_points - fractal_interpolant_data_points)) ./ abs.(last.(true_data_points)) * 100
    )
fractal_interpolant_test_points_error   = Point.( 
    abs.(last.(true_test_points - fractal_interpolant_test_points)) ./ abs.(last.(true_test_points)) * 100
    )

spline_interpolant_data_points          = map(pnt -> Point(spline_interpolant(pnt[1], pnt[2])), data_points_3d)
spline_interpolant_test_points          = map(pnt -> Point(fractal_interpolant(pnt[1], pnt[2])), test_points_3d)
spline_interpolant_data_points_error   = Point.( 
    abs.(last.(true_data_points - spline_interpolant_data_points)) ./ abs.(last.(true_data_points)) * 100
    )
spline_interpolant_test_points_error    = Point.( 
    abs.(last.(true_test_points - spline_interpolant_test_points)) ./ abs.(last.(true_test_points)) * 100
    )

# Plots 
fig = Figure(resolution=(1200, 800))
ls11 = LScene(fig[1, 1])
ls12 = LScene(fig[1, 2])
ls13 = LScene(fig[1, 3])
ls21 = LScene(fig[2, 1])
ls22 = LScene(fig[2, 2])
ls23 = LScene(fig[2, 3])

trisurf!(ls11, data_mesh_2d.position, true_data_points)
trisurf!(ls11, data_mesh_2d.position, fractal_interpolant_data_points, colormap=:heat)
wireframe!(ls11, data_mesh_2d)

trisurf!(ls12, data_mesh_2d.position, fractal_interpolant_data_points_error)
wireframe!(ls12, data_mesh_2d)

trisurf!(ls13, test_mesh_2d.position, fractal_interpolant_test_points_error)
wireframe!(ls13, test_mesh_2d)

trisurf!(ls21, data_mesh_2d.position, true_data_points)
trisurf!(ls21, data_mesh_2d.position, spline_interpolant_data_points, colormap=:heat)
wireframe!(ls21, data_mesh_2d)

trisurf!(ls22, data_mesh_2d.position, spline_interpolant_data_points_error)
wireframe!(ls22, data_mesh_2d)

trisurf!(ls23, test_mesh_2d.position, spline_interpolant_test_points_error)
wireframe!(ls23, test_mesh_2d)

fig
# Out:
# Figure()

# %% [markdown]
# #### Mean Square Error versus Number of Points
#
# This section is devoted to the analysis of number of points on the interpolation performance.

# %%
# This file includes investigates the 2D interpolation mean square error(MSE) with respect to inteprolation point number.

using FractalTools 
using GLMakie

# Construct interpolation data 
f2(x, y) = x^2 + y^2 + 1
Ω = uniformdomain(3, BigFloat)
freevar = 0.001
npts    = 50 : 5 : 150
ntpts   = 2 * npts[end]

# Construct test data 
tpts = getdata(Ω, ntpts)

# Compute errors 
mse = map(npts) do npt
    # Construct interpolation data 
    pts = getdata(f2, Ω, npt)

    # Construct interpolant 
    interp = interpolate(pts, Interp2D(freevar))

    # Compute error 
    fvals = map(pnt -> f2(pnt...), tpts)
    ivals = map(pnt -> interp(pnt...), tpts)
    sum((fvals - ivals).^2) / length(tpts)
end 

# Plot mse 
fig = Figure() 
ax = fig[1, 1] = Axis(fig, xlabel="Number of Points", ylabel="MSE", title="2D Interpolation MSE") 
stem!(ax, npts, mse, color=:black)
fig
# Out:
# ┌ Info: 50
# └ @ Main In[6]:18
# ┌ Info: 55
# └ @ Main In[6]:18
# ┌ Info: 60
# └ @ Main In[6]:18
# ┌ Info: 65
# └ @ Main In[6]:18
# ┌ Info: 70
# └ @ Main In[6]:18
# ┌ Info: 75
# └ @ Main In[6]:18
# ┌ Info: 80
# └ @ Main In[6]:18
# ┌ Info: 85
# └ @ Main In[6]:18
# ┌ Info: 90
# └ @ Main In[6]:18
# ┌ Info: 95
# └ @ Main In[6]:18
# ┌ Info: 100
# └ @ Main In[6]:18
# ┌ Info: 105
# └ @ Main In[6]:18
# ┌ Info: 110
# └ @ Main In[6]:18
# ┌ Info: 115
# └ @ Main In[6]:18
# ┌ Info: 120
# └ @ Main In[6]:18
# ┌ Info: 125
# └ @ Main In[6]:18
# ┌ Info: 130
# └ @ Main In[6]:18
# ┌ Info: 135
# └ @ Main In[6]:18
# ┌ Info: 140
# └ @ Main In[6]:18
# ┌ Info: 145
# └ @ Main In[6]:18
# ┌ Info: 150
# └ @ Main In[6]:18
# Figure()

# %% [markdown]
# #### Mean Square Error versus Number of Iterations
#
# This case deals with mean square error versus number of iterations.

# %%
# This file includes investigates the 2D interpolation mean square error(MSE) with respect to inteprolation point number.

using FractalTools 
using GLMakie 

# Construct interpolation data 
f(x, y) = x^2 + y^2 + 1
Ω = uniformdomain(6, BigFloat)
freevar = 0.001
npts    = 100
ntpts   = 2 * npts
niters  = 5 : 5 : 50

# Construct test data 
tpts = getdata(Ω, ntpts)

# Compute errors 
mse = map(niters) do niter
    @info niter
    # Construct interpolation data 
    pts = getdata(f, Ω, npts)

    # Construct interpolant 
    interp = interpolate(pts, Interp2D(freevar), niter=niter)

    # Compute error 
    fvals = map(pnt -> f(pnt...), tpts)
    ivals = map(pnt -> interp(pnt...), tpts)
    sum((fvals - ivals).^2) / length(tpts)
end 

# Plot mse 
fig = Figure() 
ax = fig[1, 1] = Axis(fig, xlabel="Number of Points", ylabel="MSE", title="2D Interpolation MSE") 
stem!(ax, niters, mse, color=:black)
fig
# Out:
# ┌ Info: 5
# └ @ Main In[8]:19
# ┌ Info: 10
# └ @ Main In[8]:19
# ┌ Info: 15
# └ @ Main In[8]:19
# ┌ Info: 20
# └ @ Main In[8]:19
# ┌ Info: 25
# └ @ Main In[8]:19
# ┌ Info: 30
# └ @ Main In[8]:19
# ┌ Info: 35
# └ @ Main In[8]:19
# ┌ Info: 40
# └ @ Main In[8]:19
# ┌ Info: 45
# └ @ Main In[8]:19
# ┌ Info: 50
# └ @ Main In[8]:19
# Figure()

# %% [markdown]
# ## 2D Hidden Fractal Interpolation
#
# ### Theory
#
# Conside the set of points
# $$
# P = \{ (x_i, y_i, z_i, t_i) ~|~ i = 1, 2, \ldots, N\}
# $$
# where $N$ is the number of points, $(x_i, y_i) \in \Omega \subset \mathbb{R}^2, z_i \in \mathbb{R}, t_i \in \mathbb{R}$. $\Omega$ is the interpolation domain with the vertex points $\{(\tilde{x}_j, \tilde{y}_j, \tilde{z}_j \tilde{z}_j) ~|~ j = 1, 2, 3\}$. The purpose is the find and interpolant $f:\Omega \mapsto \mathbb{R}^2, \; f(x,y) = (z, t)$ such that the interpolation points are satisfied, i.e., $f(x_i, y_i) = (z_i, t_i), \; i = 1, 2, \ldots, N$.
#
# The transformations $w_n$ we consider is in the form of
# $$
# w(x, y,, z, t) =
# \begin{bmatrix}
# a_{11, n}   & a_{12,n}      & 0             & 0         \\
# a_{21, n}   & a_{22, n}     & 0             & 0         \\
# a_{31, n}   & a_{32, n}     & a_{33, n}     & a_{34, n} \\
# a_{41, n}   & a_{42, n}     & a_{43, n}     & a_{44, n} \\
# \end{bmatrix}
# \begin{bmatrix}
#     x\\
#     y\\
#     z\\
#     t
# \end{bmatrix} +
# \begin{bmatrix}
#     b_{1,n} \\
#     b_{2,n} \\
#     b_{3,n} \\
#     b_{4,n}
# \end{bmatrix}
# $$
#
# Given the free variables
# $$
# \begin{bmatrix}
#     a_{33, n} & a_{34, n} \\
#     a_{43, n} & a_{44, n}
# \end{bmatrix} \quad n  = 1, 2, \ldots, K
# $$
# are the free variables, we can write the boundary conditions as
# $$
# \begin{aligned}
# w_n(\tilde{x}_1, \tilde{y}_1, \tilde{z}_1, \tilde{t}_1) &= (x_{1,n}, y_{1, n}, z_{1, n}, t_{1,n}) \\
# w_n(\tilde{x}_2, \tilde{y}_2, \tilde{z}_2, \tilde{t}_2) &= (x_{2,n}, y_{2, n}, z_{2, n}, t_{2,n}) \\
# w_n(\tilde{x}_3, \tilde{y}_3, \tilde{z}_3, \tilde{t}_3) &= (x_{3,n}, y_{3, n}, z_{3, n}, t_{3,n}) \\
# \end{aligned}
# \quad n = 1, 2, \ldots, K
# $$
# from which, we can write
# $$
# \begin{aligned}
#     a_{11, n} \tilde{x}_1 + a_{12, n} \tilde{y}_1 + b_{1, n} &= x_{1,n} \\
#     a_{11, n} \tilde{x}_2 + a_{12, n} \tilde{y}_2 + b_{1, n} &= x_{2,n} \\
#     a_{11, n} \tilde{x}_3 + a_{12, n} \tilde{y}_3 + b_{1, n} &= x_{3,n} \\
# \end{aligned}
# $$
# $$
# \begin{aligned}
#     a_{21, n} \tilde{x}_1 + a_{22, n} \tilde{y}_1 + b_{2, n} &= y_{1,n} \\
#     a_{21, n} \tilde{x}_2 + a_{22, n} \tilde{y}_2 + b_{2, n} &= y_{2,n} \\
#     a_{21, n} \tilde{x}_3 + a_{22, n} \tilde{y}_3 + b_{2, n} &= y_{3,n} \\
# \end{aligned}
# $$
# $$
# \begin{aligned}
#     a_{31, n} \tilde{x}_1 + a_{32, n} \tilde{y}_1 + b_{3, n} &= z_{1,n} - a_{33,n} \tilde{z}_1 - a_{34,n} \tilde{t}_1 \\
#     a_{31, n} \tilde{x}_2 + a_{32, n} \tilde{y}_2 + b_{3, n} &= z_{2,n} - a_{33,n} \tilde{z}_2 - a_{34,n} \tilde{t}_2\\
#     a_{31, n} \tilde{x}_3 + a_{32, n} \tilde{y}_3 + b_{3, n} &= z_{3,n} - a_{33,n} \tilde{z}_3 - a_{34,n} \tilde{t}_3 \\
# \end{aligned}
# $$
# $$
# \begin{aligned}
#     a_{41, n} \tilde{x}_1 + a_{42, n} \tilde{y}_1 + b_{4, n} &= t_{1,n} - a_{43,n} \tilde{z}_1 - a_{44,n} \tilde{t}_1 \\
#     a_{41, n} \tilde{x}_2 + a_{42, n} \tilde{y}_2 + b_{4, n} &= t_{2,n} - a_{43,n} \tilde{z}_2 - a_{44,n} \tilde{t}_2\\
#     a_{41, n} \tilde{x}_3 + a_{42, n} \tilde{y}_3 + b_{4, n} &= t_{3,n} - a_{43,n} \tilde{z}_3 - a_{44,n} \tilde{t}_3 \\
# \end{aligned}
# $$

# %% [markdown]
# Solving this set of equations for the unknowns,
# $$
# \begin{bmatrix}
# a_{11, n} & a_{21, n} & a_{31, n} & a_{41, n} \\
# a_{12, n} & a_{22, n} & a_{32, n} & a_{42, n} \\
# b_{1,n}   & b_{2, n}   & b_{3,n}   & b_{4,n}  \\
# \end{bmatrix} =
# \begin{bmatrix}
# \tilde{x}_1 & \tilde{y}_1 & 1 \\
# \tilde{x}_2 & \tilde{y}_2 & 1 \\
# \tilde{x}_3 & \tilde{y}_3 & 1 \\
# \end{bmatrix}^{-1}
# \begin{bmatrix}
# x_{1,n} & y_{1,n} & z_{1,n} - a_{33,n} \tilde{z}_1 - a_{34, n} \tilde{t}_1 & t_{1,n} - a_{43,n} \tilde{z}_1 - a_{44, n} \tilde{t}_1 \\
# x_{2,n} & y_{2,n} & z_{2,n} - a_{33,n} \tilde{z}_2 - a_{34, n} \tilde{t}_2 & t_{2,n} - a_{43,n} \tilde{z}_1 - a_{44, n} \tilde{t}_1 \\
# x_{3,n} & y_{3,n} & z_{3,n} - a_{33,n} \tilde{z}_3 - a_{34, n} \tilde{t}_3 & t_{3,n} - a_{43,n} \tilde{z}_1 - a_{44, n} \tilde{t}_1 \\
# \end{bmatrix}
# $$

# %% [markdown]
# ### Application
#
# In this section, theoretical results obtained above will be justified numerically.

# %% [markdown]
# #### Regular Data Interpolation
#
# In this section, we will consider two-dimensional hidden fractal interpolation.

# %%
using FractalTools 
using GeometryBasics
using GLMakie 

# Generate data 
f(x, y) = [
    x^2 + y^2 + 1, 
    x^2 - y^2
    ]
Ω = uniformdomain(8, BigFloat)
N = 100
pts = getdata(f, Ω, N)

# Construct intepolant 
f̃ = interpolate(pts, HInterp2D(0.01 * ones(2,2)))

# Construct test data 
tpts = getdata(Ω, N)

# Evaluations 
fvals = map(p -> f(p...) |> first, tpts)
ivals = map(p -> f̃(p...) |> first, tpts)
evals = abs.(fvals - ivals) ./ abs.(fvals) * 100

# Plots 
fig = Figure(resolution=(1200, 800)) 
ls1 = Axis3(fig[1, 1])
scatter!(ls1, project(pts))
wireframe!(ls1, tomesh(project(pts)))
scatter!(ls1, project(pts, 2))
wireframe!(ls1, tomesh(project(pts, 2)))

ls2 = Axis3(fig[1, 2])
trisurf!(ls2, tpts, fvals)
wireframe!(ls2, tomesh(project(pts, 2)))

ls3 = Axis3(fig[2, 1])
trisurf!(ls3, tpts, ivals)
wireframe!(ls3, tomesh(project(pts, 2)))

ls4 = Axis3(fig[2, 2])
trisurf!(ls4, tpts, evals)
wireframe!(ls4, tomesh(project(pts, 2)))

fig
# Out:
# Figure()

# %% [markdown]
# #### Irregular Data Interpolation
#
# In the following code block, we will investigate the interpolation performance of hidden surface fractal interpolation for
# irregular data.

# %%
using FractalTools 
using GeometryBasics
using GLMakie 

# Generate data 
f(x, y) = [
    FractalTools.rastrigin(x, y),
    sin(x) * cos(y)
    ]
Ω = uniformdomain(8, BigFloat, zeros(2), 10)
N = 100
pts = getdata(f, Ω, N)

# Construct intepolant 
f̃ = interpolate(pts, HInterp2D(0.01 * ones(2,2)))

# Construct test data 
tpts = getdata(Ω, N)

# Evaluations 
fvals = map(p -> f(p...) |> first, tpts)
ivals = map(p -> f̃(p...) |> first, tpts)
evals = abs.(fvals - ivals) ./ abs.(fvals) * 100

# Plots 
fig = Figure(resolution=(1200, 800)) 
ls1 = Axis3(fig[1, 1])
scatter!(ls1, project(pts))
wireframe!(ls1, tomesh(project(pts)))
scatter!(ls1, project(pts, 2))
wireframe!(ls1, tomesh(project(pts, 2)))

ls2 = Axis3(fig[1, 2])
trisurf!(ls2, tpts, fvals)
wireframe!(ls2, tomesh(project(pts, 2)))

ls3 = Axis3(fig[2, 1])
trisurf!(ls3, tpts, ivals)
wireframe!(ls3, tomesh(project(pts, 2)))

ls4 = Axis3(fig[2, 2])
trisurf!(ls4, tpts, evals)
wireframe!(ls4, tomesh(project(pts, 2)))

fig
# Out:
# Figure()

# %% [markdown]
# #### Effect of Free Variable
#
# To be inluded...

# %% [markdown]
# #### Mean Square Error versus Free Variable
#
# Free variable effects the mean square error of the interpolation.

# %%
# This file investigates MSE with respect to free variables 

using FractalTools 
using GeometryBasics
using GLMakie

# Construct interpolation data 
f1(x, y) = [
    x^2 + y^2 + 1, 
    sin(x) * cos(y)
]
Ω = uniformdomain(8, BigFloat, zeros(2), 10)
npts = 100
pts = getdata(f1, Ω, npts)

# Construct test data 
tpts = getdata(Ω, npts)
ntpts = length(tpts)

# Compute errors 
fvals = map(pt -> f1(pt...) |> first, tpts) 
freevars = 0.001 : 0.001 : 0.025 
mse = map(freevars) do freevar 
    interp = interpolate(pts, HInterp2D(freevar * ones(2, 2))) 
    ivals = map(pt -> interp(pt...) |> first, tpts) 
    sum((fvals - ivals).^2) / ntpts
end 

# Plot mse 
fig = Figure() 
ax = fig[1, 1] = Axis(fig, xlabel="Free Variable", ylabel="MSE", title="2D Hidden Interpolation MSE") 
stem!(ax, freevars, mse, color=:black)
fig
# Out:
# Figure()

# %% [markdown]
# #### Comparison to Spline Interpolation
#
# In the followiing code block, the fractal interpolation is compared to spline interpolation.

# %%
# Load packages 
using GLMakie 
using GeometryBasics 
using FractalTools
import Interpolations
import Interpolations: Gridded, Linear

# Define test functions 
f(x, y) = [
    x^2 + y^2 + 1, 
    sin(x) * cos(y)
]

# Construct gridded data to construct and test interpolant 
ndata = 10 
ntest = 20
data_mesh_2d = GeometryBasics.mesh(Tesselation(Rect2D(BigFloat.([-1., -1, 2., 2.])...), (ndata, ndata)))
data_points_3d = [Point(pnt..., f(pnt...)...) for pnt in data_mesh_2d.position]     # points to construct interpolants 
test_mesh_2d = GeometryBasics.mesh(Tesselation(Rect2D(BigFloat.([-1., -1, 2., 2.])...), (ntest, ntest)))
test_points_3d = [Point(pnt..., f(pnt...)...) for pnt in test_mesh_2d.position]    # points to test interpolants

# Construct interpolants 
fractal_interpolant = FractalTools.interpolate(data_points_3d, HInterp2D(0.001 * ones(2,2)))
spline_interpolant = Interpolations.interpolate(
    (unique(getindex.(data_points_3d, 1)), unique(getindex.(data_points_3d, 2))),       # x-y gridded data 
    collect(reshape(getindex.(data_points_3d, 3), ndata, ndata)),                       # z values 
    Gridded(Linear())                                                                   # Interpolation type 
)

# Evaluations 
true_data_points                        = map(pnt -> Point(f(pnt[1], pnt[2]) |> first), data_points_3d)
true_test_points                        = map(pnt -> Point(f(pnt[1], pnt[2]) |> first), test_points_3d)

fractal_interpolant_data_points         = map(pnt -> Point(fractal_interpolant(pnt[1], pnt[2]) |> first), data_points_3d)
fractal_interpolant_test_points         = map(pnt -> Point(fractal_interpolant(pnt[1], pnt[2]) |> first), test_points_3d)
fractal_interpolant_data_points_error   = Point.( 
    abs.(last.(true_data_points - fractal_interpolant_data_points)) ./ abs.(last.(true_data_points)) * 100
    )
fractal_interpolant_test_points_error   = Point.( 
    abs.(last.(true_test_points - fractal_interpolant_test_points)) ./ abs.(last.(true_test_points)) * 100
    )

spline_interpolant_data_points          = map(pnt -> Point(spline_interpolant(pnt[1], pnt[2])), data_points_3d)
spline_interpolant_test_points          = map(pnt -> Point(fractal_interpolant(pnt[1], pnt[2]) |> first), test_points_3d)
spline_interpolant_data_points_error   = Point.( 
    abs.(last.(true_data_points - spline_interpolant_data_points)) ./ abs.(last.(true_data_points)) * 100
    )
spline_interpolant_test_points_error    = Point.( 
    abs.(last.(true_test_points - spline_interpolant_test_points)) ./ abs.(last.(true_test_points)) * 100
    )

# Plots 
fig = Figure(resolution=(1200, 800))
ls11 = LScene(fig[1, 1])
ls12 = LScene(fig[1, 2])
ls13 = LScene(fig[1, 3])
ls21 = LScene(fig[2, 1])
ls22 = LScene(fig[2, 2])
ls23 = LScene(fig[2, 3])

trisurf!(ls11, data_mesh_2d.position, true_data_points)
trisurf!(ls11, data_mesh_2d.position, fractal_interpolant_data_points, colormap=:heat)
wireframe!(ls11, data_mesh_2d)

trisurf!(ls12, data_mesh_2d.position, fractal_interpolant_data_points_error)
wireframe!(ls12, data_mesh_2d)

trisurf!(ls13, test_mesh_2d.position, fractal_interpolant_test_points_error)
wireframe!(ls13, test_mesh_2d)

trisurf!(ls21, data_mesh_2d.position, true_data_points)
trisurf!(ls21, data_mesh_2d.position, spline_interpolant_data_points, colormap=:heat)
wireframe!(ls21, data_mesh_2d)

trisurf!(ls22, data_mesh_2d.position, spline_interpolant_data_points_error)
wireframe!(ls22, data_mesh_2d)

trisurf!(ls23, test_mesh_2d.position, spline_interpolant_test_points_error)
wireframe!(ls23, test_mesh_2d)

fig
# Out:
# Figure()

# %% [markdown]
# #### Mean Square Error versus Number of Points
#
# The number of interpolation points effects the interpolation performance, directly.

# %%
# This file includes investigates the 2D interpolation mean square error(MSE) with respect to inteprolation point number.

using FractalTools 
using GLMakie

# Construct interpolation data 
f2(x, y) = [
    x^2 + y^2 + 1, 
    sin(x) * cos(y)
]
Ω = uniformdomain(6, BigFloat)
freevar = 0.001
npts    = 50 : 5 : 150
ntpts   = 2 * npts[end]

# Construct test data 
tpts = getdata(Ω, ntpts)

# Compute errors 
mse = map(npts) do npt
    # Construct interpolation data 
    pts = getdata(f2, Ω, npt)

    # Construct interpolant 
    interp = interpolate(pts, HInterp2D(freevar * ones(2,2)))

    # Compute error 
    fvals = map(pnt -> f2(pnt...) |> first, tpts)
    ivals = map(pnt -> interp(pnt...) |> first, tpts)
    sum((fvals - ivals).^2) / length(tpts)
end 

# Plot mse 
fig = Figure() 
ax = fig[1, 1] = Axis(fig, xlabel="Number of Points", ylabel="MSE", title="2D Hidden Interpolation MSE") 
stem!(ax, npts, mse, color=:black)
fig
# Out:
# Figure()

# %% [markdown]
# #### Mean Square Error versus Number of Iterations
#
# Lastly, we will investigate effect of number of iterations on the interpolation performance.

# %%
using FractalTools 
using GLMakie 

# Construct interpolation data 
f(x, y) = [
    x^2 + y^2 + 1,
    sin(x) * cos(y)
]
Ω = uniformdomain(6, BigFloat)
freevar = 0.001
npts    = 100
ntpts   = 2 * npts
niters  = 5 : 5 : 50

# Construct test data 
tpts = getdata(Ω, ntpts)

# Compute errors 
mse = map(niters) do niter
    @info niter
    # Construct interpolation data 
    pts = getdata(f, Ω, npts)

    # Construct interpolant 
    interp = interpolate(pts, HInterp2D(freevar * ones(2,2)), niter=niter)

    # Compute error 
    fvals = map(pnt -> f(pnt...) |> first, tpts)
    ivals = map(pnt -> interp(pnt...) |> first, tpts)
    sum((fvals - ivals).^2) / length(tpts)
end 

# Plot mse 
fig = Figure() 
ax = fig[1, 1] = Axis(fig, xlabel="Number of Points", ylabel="MSE", title="2D Hidden Interpolation MSE") 
stem!(ax, niters, mse, color=:black)
fig
# Out:
# ┌ Info: 5
# └ @ Main In[15]:20
# ┌ Info: 10
# └ @ Main In[15]:20
# ┌ Info: 15
# └ @ Main In[15]:20
# ┌ Info: 20
# └ @ Main In[15]:20
# ┌ Info: 25
# └ @ Main In[15]:20
# ┌ Info: 30
# └ @ Main In[15]:20
# ┌ Info: 35
# └ @ Main In[15]:20
# ┌ Info: 40
# └ @ Main In[15]:20
# ┌ Info: 45
# └ @ Main In[15]:20
# ┌ Info: 50
# └ @ Main In[15]:20
# Figure()

# %% [markdown]
# ## 2D Fractal Integration

# %% [markdown]
# ### Theory
#
# We want to evaluate the following integral
# $$
# I = \int_{\Omega} f(x, y) dx dy
# $$
# where $f:\Omega \mapsto \mathbb{R}^2, \; f(x,y) = z$ is the two-dimensional fractal interpolant and $\Omega$ is the interpolation domain. Since $f$ if the fixed point of
# $$
# T[f](x, y) = F_n(L_n^{-1}(x, y), f(L_n^{-1}(x, y)))
# $$
# where
# $$
# \begin{aligned}
# L_n(x, y) &=
# \begin{bmatrix}
#     a_{11, n} & a_{12, n} \\
#     a_{21, n} & a_{22, n}
# \end{bmatrix}
# \begin{bmatrix}
#     x \\
#     y
# \end{bmatrix} +
# \begin{bmatrix}
#     b_{1,n} \\
#     b_{2,n}
# \end{bmatrix} \\
# F_n(x, y, z) &= a_{31,n} x + a_{32,n} y + a_{33,n} z + b_{3,n}
# \end{aligned}
# \quad n = 1, 2, \ldots, K
# $$

# %% [markdown]
# Thus,
# $$
# I = \int_{\Omega} f(x, y)dx dy = \int_{\Omega} Tf(x, y)dx dy = \sum_{n=1}^K \int_{\Omega_n} Tf(x, y) dx dy = \sum_{n = 1}^K \int_{\Omega_n} F_n(L_n^{-1}(x,y), f(L_n^{-1}(x,y))) dx dy
# $$
# Using the change of variable,
# $$
# (\bar{x}, \bar{y}) = L_n^{-1}(x, y) \quad \Rightarrow \quad (x, y) = L_n(\bar{x}, \bar{y})
# $$
# we have
# $$
# \begin{aligned}
# I &= \sum_{n = 1}^K \int_{\Omega} \left( a_{31, n} \bar{x} + a_{32,n} \bar{y} + a_{33,n} f(\bar{x}, \bar{y}) + b_{3, n} \right) |J_{L_n}| d\bar{x} d\bar{y} \\
# &= \sum_{n = 1}^K |J_{L_n}|  \int_{\Omega} \left( a_{31, n} \bar{x} + a_{32,n} \bar{y} + b_{3, n} \right) d\bar{x} d\bar{y} + \left( \sum_{n = 1}^K |J_{L_n}|  a_{33,n} \right) \int_{\Omega} f(\bar{x}, \bar{y}) d\bar{x} d\bar{y}
# \end{aligned}
# $$
# which can be solve for $I$,
# $$
# I = \dfrac{\sum_{n = 1}^K |J_{L_n}|  \int_{\Omega} \left( a_{31, n} \bar{x} + a_{32,n} \bar{y} + b_{3, n} \right) d\bar{x} d\bar{y}}{1 - \sum_{n = 1}^K |J_{L_n}|  a_{33,n}}
# $$

# %% [markdown]
# The integration $\int_\Omega$ can be solved by transforming $\Omega$ to unit rectangle $\Delta$. Let us define $U: \Omega \mapsto \Delta$ such that $(\bar{x}, \bar{y}) = U(\hat{x}, \hat{y})$ such that
# $$
# \begin{aligned}
# U(0, 0) &= (\bar{x}_1, \bar{y}_1) \\
# U(1, 0) &= (\bar{x}_2, \bar{y}_2) \\
# U(0, 1) &= (\bar{x}_3, \bar{y}_3) \\
# \end{aligned}
# $$
# Let $U$ be in the form
# $$
# U(\hat{x}, \hat{y}) =
# \begin{bmatrix}
#     k_{11} & k_{12} \\
#     k_{21} & k_{22}
# \end{bmatrix}
# \begin{bmatrix}
#     \hat{x} \\
#     \hat{y}
# \end{bmatrix} +
# \begin{bmatrix}
#     l_{1} \\
#     l_{2}
# \end{bmatrix}
# $$
# Using the boundary condition for $U$, we can find,
# $$
# U(\hat{x}, \hat{y}) =
# \begin{bmatrix}
#     \bar{x}_2 - \bar{x}_1 & \bar{x}_3 - \bar{x}_1 \\
#     \bar{y}_2 - \bar{y}_1 & \bar{y}_3 - \bar{y}_1
# \end{bmatrix}
# \begin{bmatrix}
#     \hat{x} \\
#     \hat{y}
# \end{bmatrix} +
# \begin{bmatrix}
#     \bar{x}_1 \\
#     \bar{y}_1
# \end{bmatrix}
# $$

# %% [markdown]
# Thus, we have
# $$
# \begin{aligned}
# I
#     &= \int_{\Omega} \left( a_{31, n} \bar{x} + a_{32,n} \bar{y} + b_{3, n} \right) d\bar{x} d\bar{y}  \\
#     &= \int_{\Delta} \left( a_{31, n} (k_{11} \hat{x} + k_{12} \hat{y} + l_1) + a_{32,n} (k_{21} \hat{x}  k_{22} \hat{y} + l_2) + b_{3, n} \right) |J_U| d\hat{x} d\hat{y}  \\
#     &= \int_{0}^{1} \int_{0}^{1 - \hat{x}} \left( a_{31, n} (k_{11} \hat{x} + k_{12} \hat{y} + l_1) + a_{32,n} (k_{21} \hat{x}  k_{22} \hat{y} + l_2) + b_{3, n} \right) |J_U| d\hat{y} d\hat{x}  \\
#     &= |J_U| \left( \dfrac{a_{31,n}}{6} (k_{11} + k_{12} + 3 l_1) + \dfrac{a_{32,n}}{6} (k_{21} + k_{22} + 3 l_2)  + \dfrac{b_{3,n}}{2}  \right)
# \end{aligned}
# $$

# %% [markdown]
# Hence, we have,
# $$
# \begin{aligned}
# I
# &= \dfrac{|J_U|}{6} \dfrac{\sum_{n = 1}^K |J_{L_n}|  \left( a_{31,n} (k_{11} + k_{12} + 3 l_1) + a_{32,n} (k_{21} + k_{22} + 3 l_2)  + 3 b_{3,n}  \right)  }{1 - \sum_{n = 1}^K |J_{L_n}|  a_{33,n}} \\
# &= \dfrac{k_{11} k_{22} - k_{12} k_{21}}{6} \dfrac{\sum_{n = 1}^K |J_{L_n}|  \left( a_{31,n} (k_{11} + k_{12} + 3 l_1) + a_{32,n} (k_{21} + k_{22} + 3 l_2)  + 3 b_{3,n}  \right)  }{1 - \sum_{n = 1}^K |J_{L_n}|  a_{33,n}}
# \end{aligned}
# $$

# %% [markdown]
# ## Application
#
# In this section, theoretical results obtained above will be justified numerically.

# %% [markdown]
# #### Integration Error
#
# To be inluded...

# %% [markdown]
# #### Running Integration
#
# To be included....

# %% [markdown]
# ## 2D Fractal Hidden Fractal Integration
#
# ### Theory
#
# Consider the integration
# $$
# I = \int_{\Omega} f(x, y)dx dy
# $$
# where $f: \Omage \mapsto \mathbb{R}^2$ is a hidden fractal interpolant. We can write
# $$
# I = \begin{bmatrix}
#     I_1 \\
#     I_2
# \end{bmatrix} = \begin{bmatrix}
#     \int_{\Omega} f_1(x, y) dx dy \\
#     \int_{\Omega} f_2(x, y) dx dy
# \end{bmatrix}
# $$
# where $f(x, y) = [f_1(x, y), f_2(x, y)], \; f_1 : \Omega \mapsto \mathbb{R}, \; f_2: \Omega \mapsto \mathbb{R}$ is used.

# %% [markdown]
# Since $f$ is the fixed point of the mapping
# $$
# T[f](x, y) = F_n(L_n^{-1}(x, y), f(L_n^{-1}(x, y))
# $$
# where
# $$
# \begin{aligned}
# L_n(x, y) &= \begin{bmatrix}
#     a_{11, n} & a_{12, n} \\
#     a_{21, n} & a_{22, n}
# \end{bmatrix}
# \begin{bmatrix}
#     x \\
#     y
# \end{bmatrix} +
# \begin{bmatrix}
#     b_{1,n}\\
#     b_{2,n}
# \end{bmatrix} \\
# F_n(x, y, z, t) &= \begin{bmatrix}
#     a_{31,n} & a_{32,n} & a_{33,n} & a_{34,n} \\
#     a_{41,n} & a_{42,n} & a_{43,n} & a_{44,n}
# \end{bmatrix}
# \begin{bmatrix}
#     x\\
#     y\\
#     z\\
#     t
# \end{bmatrix} +
# \begin{bmatrix}
#     b_{3,n} \\
#     b_{4,n}
# \end{bmatrix}
# \end{aligned}
# $$

# %% [markdown]
# we can write
# $$
# \begin{aligned}
# I &= \int_{\Omega} Tf(x, y) dx dy = \sum_{n = 1}^K \int_{\Omega_n} F_n(L_n^{-1}(x,y), f(L_n^{-1}(x,y)))dxdy
# \end{aligned}
# $$
# Usign the transformation
# $$
# (x, y) = L_n(\bar{x}, \bar{y}) \quad \Rightarrow \quad (\bar{x}, \bar{y}) = L_n^{-1}(x, y)
# $$
# we have
# $$
# \begin{aligned}
# I &= \sum_{n=1}^K \int_{\Omega} F_n(\bar{x}, \bar{y}, f(\bar{x}, \bar{y})) |J_{L_n}| d\bar{x} d\bar{y} \\
# &= \begin{bmatrix}
# I_1 \\
# I_2
# \end{bmatrix} = \begin{bmatrix}
# \sum_{n = 1}^K \int_{\Omega} \left( a_{31,n} \bar{x} + a_{32, n} \bar{y} + a_{33, n} f_1(\bar{x}, \bar{y}) + a_{34,n} f_2(\bar{x}, \bar{y}) + b_{3,n} \right) |J_{L_n}| d\bar{x} d\bar{y} \\
# \sum_{n = 1}^K \int_{\Omega} \left( a_{41,n} \bar{x} + a_{42, n} \bar{y} + a_{43, n} f_1(\bar{x}, \bar{y}) + a_{44,n} f_2(\bar{x}, \bar{y}) + b_{4,n} \right) |J_{L_n}| d\bar{x} d\bar{y} \\
# \end{bmatrix} \\
# &= \begin{bmatrix}
# \sum_{n = 1}^K |J_{L_n}| \int_{\Omega} \left( a_{31,n} \bar{x} + a_{32, n} \bar{y} + b_{3,n} \right) d\bar{x} d\bar{y} + \left( \sum_{n=1}^K |J_{L_n}|  a_{33, n} \right) I_1 + \left( \sum_{n = 1}^K |J_{L_n}| a_{34,n} \right) I_2 \\
# \sum_{n = 1}^K |J_{L_n}| \int_{\Omega} \left( a_{41,n} \bar{x} + a_{42, n} \bar{y} + b_{4,n} \right) d\bar{x} d\bar{y} + \left( \sum_{n=1}^K |J_{L_n}|  a_{43, n} \right) I_1 + \left( \sum_{n = 1}^K |J_{L_n}| a_{44,n} \right) I_2 \\
# \end{bmatrix} \\
# &= \begin{bmatrix}
#     \Lambda_1 + W_{11} I_1 + W_{12} I_2 \\
#     \Lambda_2 + W_{12} I_1 + W_{22} I_2 \\
# \end{bmatrix}
# \end{aligned}
# $$
# Solving for $I_1$ and $I_2$, we have
# $$
# \begin{bmatrix}
#     I_1 \\
#     I_2
# \end{bmatrix} =
# \begin{bmatrix}
#      1 - W_{11} & -W_{12} \\
#      -W_{21} & 1 - W_{22}
# \end{bmatrix}^{-1}
# \begin{bmatrix}
#     \Lambda_1 \\
#     \Lambda_2
# \end{bmatrix}
# $$
# where
# $$
# \begin{aligned}
# W_{11} &= \sum_{n=1}^K |J_{L_n}| a_{33,n} \\
# W_{12} &= \sum_{n=1}^K |J_{L_n}| a_{34,n} \\
# W_{21} &= \sum_{n=1}^K |J_{L_n}| a_{43,n} \\
# W_{22} &= \sum_{n=1}^K |J_{L_n}| a_{44,n} \\
# \Lambda_{1} &= \sum_{n = 1}^K |J_{L_n}| \int_{\Omega} \left( a_{31,n} \bar{x} + a_{32, n} \bar{y} + b_{3,n} \right) d\bar{x} d\bar{y} \\
# \Lambda_{2} &= \sum_{n = 1}^K |J_{L_n}| \int_{\Omega} \left( a_{41,n} \bar{x} + a_{42, n} \bar{y} + b_{4,n} \right) d\bar{x} d\bar{y}
# \end{aligned}
# $$

# %% [markdown]
# The integral $\int_\Omega$ can be computed on a unit rectangle $\Delta$. Let $U:\Omega \mapsto \Delta, \; T(\hat{x}, \hat{y}) = (\bar{x}, \bar{y})$ such that
# $$
# \begin{aligned}
#     U(0, 0) &= (\bar{x}_1, \bar{y}_1) \\
#     U(1, 0) &= (\bar{x}_2, \bar{y}_2) \\
#     U(0, 1) &= (\bar{x}_3, \bar{y}_3)
# \end{aligned}
# $$
# Let $U$ be in the form,
# $$
# U =
# \begin{bmatrix}
#     k_{11} & k_{12} \\
#     k_{21} & k_{22}
# \end{bmatrix}
# \begin{bmatrix}
#     \hat{x} \\
#     \hat{y}
# \end{bmatrix} +
# \begin{bmatrix}
#     l_1 \\
#     l_2
# \end{bmatrix}
# $$
# Using the boundary conditions of $U$, we can find,
# $$
# U =
# \begin{bmatrix}
#     \bar{x}_2 - \bar{x}_1 & \bar{x}_3 - \bar{x}_1 \\
#     \bar{y}_2 - \bar{y}_1 & \bar{y}_3 - \bar{y}_1
# \end{bmatrix}
# \begin{bmatrix}
#     \hat{x} \\
#     \hat{y}
# \end{bmatrix} +
# \begin{bmatrix}
#     \bar{x}_1 \\
#     \bar{y}_1
# \end{bmatrix}
# $$
# Then, we can write
# $$
# \begin{aligned}
# \int_{\Omega} \left( a_{31,n} \bar{x} + a_{32, n} \bar{y} + b_{3,n} \right) d\bar{x} d\bar{y} &= \int_{\Delta} \left( a_{31,n} (k_{11} \hat{x} + k_{12} \hat{y} + l_1) + a_{32, n} (k_{21} \hat{x} + k_{22} \hat{y} + l_2) + b_{3,n} \right) |J_U| d\hat{x} d\hat{y} \\
# &= \dfrac{|J_U|}{6}\left( a_{31,n} (k_{11} + k_{12} + 3 l_1) + a_{32,n} (k_{21} + k_{22} + 3 l_2) + 3 b_{3,n} \right)
# \end{aligned}
# $$
# Similarly,
# $$
# \begin{aligned}
# \int_{\Omega} \left( a_{41,n} \bar{x} + a_{42, n} \bar{y} + b_{4,n} \right) d\bar{x} d\bar{y} &= \int_{\Delta} \left( a_{41,n} (k_{11} \hat{x} + k_{12} \hat{y} + l_1) + a_{42, n} (k_{21} \hat{x} + k_{22} \hat{y} + l_2) + b_{4,n} \right) |J_U| d\hat{x} d\hat{y} \\
# &= \dfrac{|J_U|}{6}\left( a_{41,n} (k_{11} + k_{12} + 3 l_1) + a_{42,n} (k_{21} + k_{22} + 3 l_2) + 3 b_{4,n} \right)
# \end{aligned}
# $$
# Thus,
# $$
# \begin{aligned}
# W_{11} &= \sum_{n=1}^K |J_{L_n}| a_{33,n} \\
# W_{12} &= \sum_{n=1}^K |J_{L_n}| a_{34,n} \\
# W_{21} &= \sum_{n=1}^K |J_{L_n}| a_{43,n} \\
# W_{22} &= \sum_{n=1}^K |J_{L_n}| a_{44,n} \\
# \Lambda_{1} &= \dfrac{|J_U|}{6} \sum_{n = 1}^K |J_{L_n}| \left( a_{31,n} (k_{11} + k_{12} + 3 l_1) + a_{32,n} (k_{21} + k_{22} + 3 l_2) + 3 b_{3,n} \right) \\
# \Lambda_{2} &= \dfrac{|J_U|}{6} \sum_{n = 1}^K |J_{L_n}| \left( a_{41,n} (k_{11} + k_{12} + 3 l_1) + a_{42,n} (k_{21} + k_{22} + 3 l_2) + 3 b_{4,n} \right)
# \end{aligned}
# $$
# and
# $$
# \begin{bmatrix}
#     I_1 \\
#     I_2
# \end{bmatrix} =
# \begin{bmatrix}
#      1 - W_{11} & -W_{12} \\
#      -W_{21} & 1 - W_{22}
# \end{bmatrix}^{-1}
# \begin{bmatrix}
#     \Lambda_1 \\
#     \Lambda_2
# \end{bmatrix}
# $$

# %% [markdown]
# ### Application
#
# In this section, theoretical results obtained above will be justified numerically.

# %% [markdown]
# #### Integration Error
#
# To be included...

# %% [markdown]
# #### Running Integration
#
# To be included....
